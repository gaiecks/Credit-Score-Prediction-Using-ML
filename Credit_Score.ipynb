# %% [markdown]
# <a href="https://colab.research.google.com/github/gaiecks/Credit-Score-Prediction-Using-ML/blob/main/Credit_Score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neste projeto temos o objetivo de criar um modelo preditivo de Score de Credito de clientes utilizando Machine Learning.
# Passaremos por etapas de analise exploratória de dados e criação de visualizações, tratamento de dados, tratamento de valores missing, engenharia de atributos, normalização dos dados, OneHotEncoding além de criar, treinar e testar um modelo de Machine Learning para enfim prever Score de Clientes baseados nas variáveis de entrada.

# %% [markdown]
# Vamos iniciar importando todas as bibliotecas necessárias, o arquivo base e analisando sua estrutura:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score


#exibir todas colunas do arquivo
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_dados = pd.read_excel("/content/drive/MyDrive/análise de dados/dados_credito.xlsx")

# %%
df_dados.shape
# Out:
# (10476, 17)

# %%
df_dados.columns
# Out:
# Index(['CODIGO_CLIENTE', 'UF', 'IDADE', 'ESCOLARIDADE', 'ESTADO_CIVIL',
#        'QT_FILHOS', 'CASA_PROPRIA', 'QT_IMOVEIS', 'VL_IMOVEIS', 'OUTRA_RENDA',
#        'OUTRA_RENDA_VALOR', 'TEMPO_ULTIMO_EMPREGO_MESES',
#        'TRABALHANDO_ATUALMENTE', 'ULTIMO_SALARIO', 'QT_CARROS',
#        'VALOR_TABELA_CARROS', 'SCORE'],
#       dtype='object')

# %%
df_dados.head()
# Out:
#    CODIGO_CLIENTE  UF  IDADE           ESCOLARIDADE ESTADO_CIVIL  QT_FILHOS  \
# 0               1  SP     19      Superior Cursando     Solteiro          0
# 1               2  MG     23      Superior Completo     Solteiro          1
# 2               3  SC     25  Segundo Grau Completo       Casado          0
# 3               4  PR     27      Superior Cursando       Casado          1
# 4               5  RJ     28      Superior Completo   Divorciado          2
#
#   CASA_PROPRIA  QT_IMOVEIS  VL_IMOVEIS OUTRA_RENDA  OUTRA_RENDA_VALOR  \
# 0          Não           0           0         Não                  0
# 1          Não           0           0         Não                  0
# 2          Sim           1      220000         Não                  0
# 3          Sim           0           0         Não                  0
# 4          Não           1      370000         Não                  0
#
#    TEMPO_ULTIMO_EMPREGO_MESES TRABALHANDO_ATUALMENTE ULTIMO_SALARIO  \
# ...

# %%
df_dados.tail()
# Out:
#        CODIGO_CLIENTE  UF  IDADE           ESCOLARIDADE ESTADO_CIVIL  \
# 10471           10472  PR     51      Superior Completo     Solteiro
# 10472           10473  SP     48  Segundo Grau Completo       Casado
# 10473           10474  RJ     51      Superior Cursando       Casado
# 10474           10475  RJ     48      Superior Completo   Divorciado
# 10475           10476  PR     51  Segundo Grau Completo   Divorciado
#
#        QT_FILHOS CASA_PROPRIA  QT_IMOVEIS  VL_IMOVEIS OUTRA_RENDA  \
# 10471          1          Não           0           0         Não
# 10472          0          Sim           1      220000         Não
# 10473          1          Sim           0           0         Não
# 10474          2          Não           1      370000         Não
# 10475          0          Não           0           0         Não
#
#        OUTRA_RENDA_VALOR  TEMPO_ULTIMO_EMPREGO_MESES TRABALHANDO_ATUALMENTE  \
# ...

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10476 entries, 0 to 10475
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CODIGO_CLIENTE              10476 non-null  int64
#  1   UF                          10476 non-null  object
#  2   IDADE                       10476 non-null  int64
#  3   ESCOLARIDADE                10476 non-null  object
#  4   ESTADO_CIVIL                10476 non-null  object
#  5   QT_FILHOS                   10476 non-null  int64
#  6   CASA_PROPRIA                10476 non-null  object
#  7   QT_IMOVEIS                  10476 non-null  int64
#  8   VL_IMOVEIS                  10476 non-null  int64
#  9   OUTRA_RENDA                 10476 non-null  object
#  10  OUTRA_RENDA_VALOR           10476 non-null  int64
#  11  TEMPO_ULTIMO_EMPREGO_MESES  10476 non-null  int64
#  12  TRABALHANDO_ATUALMENTE      10476 non-null  object
# ...

# %% [markdown]
# A partir da análise do dataset, podemos destacar que:
# 1. Variável "CODIGO_CLIENTE" PODE SER EXCLUÍDA.
# 2. Variáveis com Dtype = object (strings) precisam de onehotencoding, para trabalharmos com valores numéricos.
# 3. Variável "ULTIMO_SALÁRIO" por algum motivo foi importada como string e precisamos tratá-la para que possua valores numéricos.

# %%
#excluindo a coluna "CODIGO_CLIENTE":
df_dados.drop('CODIGO_CLIENTE', axis=1, inplace=True)

# %%
df_dados.groupby(['ULTIMO_SALARIO']).size()
# Out:
# ULTIMO_SALARIO
# 1800         846
# 2200         792
# 3100         792
# 3900         792
# 4500         468
# 4800         792
# 5300         522
# 6100         522
# 6800         611
# 9000         522
# 9800         468
# 11500        790
# 13000        522
# 15000        522
# 17500        522
# 18300        522
# 22000        468
# SEM DADOS      1
# dtype: int64

# %% [markdown]
# vemos que 1 dado está como string e por isso tudo foi importado como string.

# %%
df_dados.loc[df_dados['ULTIMO_SALARIO'] == 'SEM DADOS']
# Out:
#        UF  IDADE       ESCOLARIDADE ESTADO_CIVIL  QT_FILHOS CASA_PROPRIA  \
# 10459  RJ     45  Superior Cursando     Solteiro          1          Sim
#
#        QT_IMOVEIS  VL_IMOVEIS OUTRA_RENDA  OUTRA_RENDA_VALOR  \
# 10459           1      185000         Sim               3000
#
#        TEMPO_ULTIMO_EMPREGO_MESES TRABALHANDO_ATUALMENTE ULTIMO_SALARIO  \
# 10459                          19                    Sim      SEM DADOS
#
#        QT_CARROS  VALOR_TABELA_CARROS      SCORE
# 10459          0                    0  45.166667

# %%
# Substituindo a palavra SEM VALOR por um valor NULO
df_dados.replace('SEM DADOS',np.nan, inplace = True)

# %%
# Convertendo o campo em float
df_dados['ULTIMO_SALARIO'] = df_dados['ULTIMO_SALARIO'].astype(np.float64)

# %%
#verificando se há valores nulos
df_dados.isnull().sum()
# Out:
# UF                            0
# IDADE                         0
# ESCOLARIDADE                  0
# ESTADO_CIVIL                  0
# QT_FILHOS                     0
# CASA_PROPRIA                  0
# QT_IMOVEIS                    0
# VL_IMOVEIS                    0
# OUTRA_RENDA                   0
# OUTRA_RENDA_VALOR             0
# TEMPO_ULTIMO_EMPREGO_MESES    0
# TRABALHANDO_ATUALMENTE        0
# ULTIMO_SALARIO                3
# QT_CARROS                     0
# VALOR_TABELA_CARROS           0
# SCORE                         0
# dtype: int64

# %%
# Atualizando os valores nulos (fillna) com mediana do modelo
df_dados['ULTIMO_SALARIO'] = df_dados['ULTIMO_SALARIO'].fillna((df_dados['ULTIMO_SALARIO'].median()))

# %%
# Avaliando algumas medidas estatísticas básicas
df_dados.describe()
# Out:
#               IDADE     QT_FILHOS    QT_IMOVEIS     VL_IMOVEIS  \
# count  10476.000000  10476.000000  10476.000000   10476.000000
# mean      41.054124      1.122566      0.847079  238453.608247
# std       13.878162      1.113537      0.957374  265843.934416
# min       19.000000      0.000000      0.000000       0.000000
# 25%       28.000000      0.000000      0.000000       0.000000
# 50%       42.000000      1.000000      1.000000  185000.000000
# 75%       53.000000      2.000000      1.000000  370000.000000
# max       65.000000     42.000000      3.000000  900000.000000
#
#        OUTRA_RENDA_VALOR  TEMPO_ULTIMO_EMPREGO_MESES  ULTIMO_SALARIO  \
# count       10476.000000                10476.000000    10476.000000
# mean          641.237113                   43.070447     8286.531119
# std          1295.978195                   40.851521     5826.589775
# min             0.000000                    8.000000     1800.000000
# ...

# %%
# Avaliando os outliers das colunas que são númericas
# Vamos criar uma lista com as variaveis que são do tipo INT64 E FLOAT64
variaveis_numericas = []
for i in df_dados.columns[0:16].tolist(): #varrendo as colunas de 0 a 16; existem 15 colunas, então vai parar no 15.
        if df_dados.dtypes[i] == 'int64' or df_dados.dtypes[i] == 'float64':
            print(df_dados.columns.get_loc(i), i, ':' , df_dados.dtypes[i])
            variaveis_numericas.append(i)
# Out:
# 1 IDADE : int64
# 4 QT_FILHOS : int64
# 6 QT_IMOVEIS : int64
# 7 VL_IMOVEIS : int64
# 9 OUTRA_RENDA_VALOR : int64
# 10 TEMPO_ULTIMO_EMPREGO_MESES : int64
# 12 ULTIMO_SALARIO : float64
# 13 QT_CARROS : int64
# 14 VALOR_TABELA_CARROS : int64
# 15 SCORE : float64

# %%
variaveis_numericas
# Out:
# ['IDADE',
#  'QT_FILHOS',
#  'QT_IMOVEIS',
#  'VL_IMOVEIS',
#  'OUTRA_RENDA_VALOR',
#  'TEMPO_ULTIMO_EMPREGO_MESES',
#  'ULTIMO_SALARIO',
#  'QT_CARROS',
#  'VALOR_TABELA_CARROS',
#  'SCORE']

# %%
# exibindo todos os gráficos de todas as colunas de uma vez só:

# Tamanho da tela para exibição dos gráficos
plt.rcParams["figure.figsize"] = [15.00, 12.00]
plt.rcParams["figure.autolayout"] = True

# Quantidade de linhas e colunas queremos exibir os gráficos
f, axes = plt.subplots(2, 5)

linha = 0
coluna = 0

for i in variaveis_numericas:
    sns.boxplot(data = df_dados, y=i, ax=axes[linha][coluna])
    coluna += 1
    if coluna == 5:
        linha += 1
        coluna = 0

plt.show()

# %% [markdown]
# A partir da análise dos gráficos BoxPlot para identificação de outliers, percebemos que provavelmente o único outlier está presente na variável de quantidade de filhos (QT_FILHOS), pois não faz sentido alguém ter cerca de 40 filhos. Os demais "outliers" podem representar dados de fato reais, mas vamos analisar.

# %%
df_dados.loc[df_dados['QT_FILHOS'] > 4]
# Out:
#        UF  IDADE           ESCOLARIDADE ESTADO_CIVIL  QT_FILHOS CASA_PROPRIA  \
# 27     SP     48      Superior Completo   Divorciado         38          Sim
# 10455  SP     45  Segundo Grau Completo       Casado         42          Sim
#
#        QT_IMOVEIS  VL_IMOVEIS OUTRA_RENDA  OUTRA_RENDA_VALOR  \
# 27              2      600000         Não                  0
# 10455           1      220000         Não                  0
#
#        TEMPO_ULTIMO_EMPREGO_MESES TRABALHANDO_ATUALMENTE  ULTIMO_SALARIO  \
# 27                             15                    Sim         15000.0
# 10455                          18                    Sim          2200.0
#
#        QT_CARROS  VALOR_TABELA_CARROS      SCORE
# 27             1                70000  67.166667
# 10455          2                30000  23.000000

# %%
# Nesse exemplo vamos excluir o registro todo.
df_dados.drop(df_dados.loc[df_dados['QT_FILHOS'] > 4].index, inplace=True)

# %% [markdown]
# Abaixo vamos analisar as outra variáveis com possíveis outliers para entender se de fato são ou não. para isso usaremos a função .size para entender a distribuição dos valores:

# %%
df_dados.groupby(['OUTRA_RENDA_VALOR']).size()
# Out:
# OUTRA_RENDA_VALOR
# 0       8350
# 2400     468
# 3000     612
# 3200     522
# 4000     522
# dtype: int64

# %%
df_dados.groupby(['VALOR_TABELA_CARROS']).size()
# Out:
# VALOR_TABELA_CARROS
# 0         3762
# 28000      468
# 30000      791
# 35000      792
# 40000      792
# 48000      522
# 50000     1314
# 70000      521
# 80000      522
# 150000     468
# 180000     522
# dtype: int64

# %%
df_dados.groupby(['QT_IMOVEIS']).size()
# Out:
# QT_IMOVEIS
# 0    4680
# 1    3761
# 2     989
# 3    1044
# dtype: int64

# %% [markdown]
# Verificamos que de fato não podemos considerar essas variáveis como outliers pois representam dados significantes dentro do nosso dataframe.

# %%
# Vamos gerar gráficos de histograma para avaliar a distribuição dos dados,
# de semelhante modo aos boxplots que plotamos momentos atrás

# tamanho da tela para exibição dos gráficos
plt.rcParams["figure.figsize"] = [15.00, 12.00]
plt.rcParams["figure.autolayout"] = True

# qtd de linhas e colunas queremos exibir os gráficos
f, axes = plt.subplots(4, 3)

linha = 0
coluna = 0

for i in variaveis_numericas:
    sns.histplot(data = df_dados, x=i, ax=axes[linha][coluna])
    coluna += 1
    if coluna == 3:
        linha += 1
        coluna = 0

plt.show()

# %% [markdown]
# Vamos criar um heatmap para entender a correlação entre todas as variáveis numéricas do dataframe:

# %%
# Seleção de colunas numéricas
numerical_df = df_dados.select_dtypes(include=['int64', 'float64'])
# Cálculo da correlação
corr = numerical_df.corr()
# Configuração do tamanho da figura
plt.rcParams["figure.figsize"] = (18, 8)
# Plotagem do heatmap
ax = sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Heatmap de Correlação entre Variáveis Numéricas')

# Exibir o gráfico
plt.show()

# %% [markdown]
# Foram selecionadas 3 variáveis com índice de correlação alto com a variável alvo Score. Vamos plotar gráficos de dispersão para avaliar a correlação dessas variáveis, que são: VL_IMOVEL, ULTIMO_SALARIO e TEMPO_ULTIMO_EMPREGO_MESES.

# %%
sns.lmplot(x = "VL_IMOVEIS", y = "SCORE", data = df_dados);

# %%
sns.lmplot(x = "ULTIMO_SALARIO", y = "SCORE", data = df_dados);

# %%
sns.lmplot(x = "TEMPO_ULTIMO_EMPREGO_MESES", y = "SCORE", data = df_dados);

# %% [markdown]
# Vamos agora criar uma nova variável que será chamada FAIXA_ETARIA para categorizar os dados de idade em grupos.
# Para isso, analisaremos a maior e menor idade e posteriormente dividiremos nos grupos pertinentes.

# %%
print('Menor Idade: ', df_dados['IDADE'].min())
print('Maior Idade: ', df_dados['IDADE'].max())
# Out:
# Menor Idade:  19
# Maior Idade:  65

# %%
# Criar as faixas etárias
idade_bins = [0, 30, 40, 50, 60]
idade_categoria = ["Até 30", "31 a 40", "41 a 50", "Maior que 50"]

# Garantir que não há valores fora dos intervalos especificados
df_dados["IDADE"] = df_dados["IDADE"].apply(lambda x: x if 0 <= x <= 60 else None)

# Aplicar a função cut para criar as faixas etárias
df_dados["FAIXA_ETARIA"] = pd.cut(df_dados["IDADE"], idade_bins, labels=idade_categoria)

df_dados["FAIXA_ETARIA"].value_counts()
# Out:
# FAIXA_ETARIA
# Até 30          3552
# Maior que 50    2448
# 41 a 50         2070
# 31 a 40         1270
# Name: count, dtype: int64

# %%
# Avaliar a média do score pela faixa etária
media_score_faixa_etaria = df_dados.groupby("FAIXA_ETARIA")["SCORE"].mean()

print(media_score_faixa_etaria)
# Out:
# FAIXA_ETARIA
# Até 30          44.762950
# 31 a 40         48.883202
# 41 a 50         51.440177
# Maior que 50    56.123775
# Name: SCORE, dtype: float64

# %%
# vamos criar uma lista de variáveis categóricas que podem ser do tipo object ou category
variaveis_categoricas = []
for i in df_dados.columns[0:48].tolist():
        if df_dados.dtypes[i] == 'object' or df_dados.dtypes[i] == 'category':
            print(i, ':' , df_dados.dtypes[i])
            variaveis_categoricas.append(i)
# Out:
# UF : object
# ESCOLARIDADE : object
# ESTADO_CIVIL : object
# CASA_PROPRIA : object
# OUTRA_RENDA : object
# TRABALHANDO_ATUALMENTE : object
# FAIXA_ETARIA : category

# %%
# Vamos exibir todos os gráficos de todas as colunas dessas variáveis de uma vez só para facilitar a analise.

# Tamanho da tela para exibição dos gráficos
plt.rcParams["figure.figsize"] = [15.00, 22.00]
plt.rcParams["figure.autolayout"] = True

# Aqui definimos em quantas linhas e colunas queremos exibir os gráficos
f, axes = plt.subplots(4, 2)

linha = 0
coluna = 0

for i in variaveis_categoricas:
    sns.countplot(data = df_dados, x=i, ax=axes[linha][coluna])

    coluna += 1
    if coluna == 2:
        linha += 1
        coluna = 0

# %% [markdown]
# Agora vamos criar um encoder para definir valores numéricos para variáveis que estão como texto.

# %%
# Cria o encoder
lb = LabelEncoder()

# Aplica o encoder nas variáveis que estão com string
df_dados['FAIXA_ETARIA'] = lb.fit_transform(df_dados['FAIXA_ETARIA'])
df_dados['OUTRA_RENDA'] = lb.fit_transform(df_dados['OUTRA_RENDA'])
df_dados['TRABALHANDO_ATUALMENTE'] = lb.fit_transform(df_dados['TRABALHANDO_ATUALMENTE'])
df_dados['ESTADO_CIVIL'] = lb.fit_transform(df_dados['ESTADO_CIVIL'])
df_dados['CASA_PROPRIA'] = lb.fit_transform(df_dados['CASA_PROPRIA'])
df_dados['ESCOLARIDADE'] = lb.fit_transform(df_dados['ESCOLARIDADE'])
df_dados['UF'] = lb.fit_transform(df_dados['UF'])

# Remove valores missing eventualmente gerados
df_dados.dropna(inplace = True)

# %%
df_dados.head(200)
# Out:
#      UF  IDADE  ESCOLARIDADE  ESTADO_CIVIL  QT_FILHOS  CASA_PROPRIA  \
# 0     4   19.0             2             2          0             0
# 1     0   23.0             1             2          1             0
# 2     3   25.0             0             0          0             1
# 3     1   27.0             2             0          1             1
# 4     2   28.0             1             1          2             0
# 5     4   30.0             0             1          0             0
# 6     0   32.0             2             2          1             1
# 7     3   35.0             1             2          1             1
# 8     1   42.0             0             0          0             0
# 9     2   45.0             2             0          0             0
# 10    4   48.0             1             1          2             1
# 11    0   51.0             0             1          1             1
# 12    3   53.0             2             0          2             0
# ...

# %% [markdown]
# A partir daqui vamos começar a criar um modelo e treiná-lo.

# %%
# Separando a variavel alvo
# pegar todas as linhas da coluna 15 a 16, porém, ele para antes da 16.
target = df_dados.iloc[:,15:16]

# %%
# Separando as variaveis preditoras

preditoras = df_dados.copy() #Fazendo uma cópia do dataframe

del preditoras['SCORE'] #Excluindo a variavel target, pois já separamos ela na etapa anterior

preditoras.head()#Visualizando as variaveis preditoras
# Out:
#    UF  IDADE  ESCOLARIDADE  ESTADO_CIVIL  QT_FILHOS  CASA_PROPRIA  QT_IMOVEIS  \
# 0   4   19.0             2             2          0             0           0
# 1   0   23.0             1             2          1             0           0
# 2   3   25.0             0             0          0             1           1
# 3   1   27.0             2             0          1             1           0
# 4   2   28.0             1             1          2             0           1
#
#    VL_IMOVEIS  OUTRA_RENDA  OUTRA_RENDA_VALOR  TEMPO_ULTIMO_EMPREGO_MESES  \
# 0           0            0                  0                           8
# 1           0            0                  0                           9
# 2      220000            0                  0                          18
# 3           0            0                  0                          22
# 4      370000            0                  0                          30
#
# ...

# %%
# Divisão em Dados de Treino e Teste.
# Os dados de teste serão 30%.
X_treino, X_teste, y_treino, y_teste = train_test_split(preditoras, target, test_size = 0.3, random_state = 40)

# %%
# Aplicando a normalização em treino e teste
sc = MinMaxScaler()
X_treino_normalizados = sc.fit_transform(X_treino)
X_teste_normalizados = sc.transform(X_teste)

# %% [markdown]
# Criando, avaliando e testando o modelo preditivo:

# %%
# Treina o modelo
modelo = LinearRegression()

modelo = modelo.fit(X_treino_normalizados, y_treino)

# %%
r2_score(y_teste, modelo.fit(X_treino_normalizados, y_treino).predict(X_teste_normalizados))
# Out:
# 0.7917230480601337

# %% [markdown]
# O valor acima (cerca de 79%) representa a acurácia do modelo preditivo. isso quer dizer que para cada 100 clientes, ele acertará por volta de 79. Podemos considerar uma boa acurácia para nos dizer qual deve ser o Score de Crédito do cliente.

# %% [markdown]
# Simulando uma situação imputando dados nas colunas com informações que dizem respeito a um potencial cliente:

# %%
UF = 2
IDADE = 42
ESCOLARIDADE = 1
ESTADO_CIVIL = 2
QT_FILHOS = 1
CASA_PROPRIA = 1
QT_IMOVEIS = 1
VL_IMOVEIS = 300000
OUTRA_RENDA = 1
OUTRA_RENDA_VALOR = 2000
TEMPO_ULTIMO_EMPREGO_MESES = 18
TRABALHANDO_ATUALMENTE = 1
ULTIMO_SALARIO = 5400.0
QT_CARROS = 4
VALOR_TABELA_CARROS = 70000
FAIXA_ETARIA = 3

novos_dados = [UF, IDADE, ESCOLARIDADE, ESTADO_CIVIL, QT_FILHOS,CASA_PROPRIA,QT_IMOVEIS,VL_IMOVEIS,OUTRA_RENDA,
               OUTRA_RENDA_VALOR,TEMPO_ULTIMO_EMPREGO_MESES,TRABALHANDO_ATUALMENTE,ULTIMO_SALARIO,QT_CARROS,
               VALOR_TABELA_CARROS, FAIXA_ETARIA]


# Reshape
X = np.array(novos_dados).reshape(1, -1)
X = sc.transform(X)

# Previsão
print("Score de crédito previsto para esse cliente:", modelo.predict(X))
# Out:
# Score de crédito previsto para esse cliente: [[46.15312722]]

# %% [markdown]
# As variáveis podem ser alteradas para simular diferentes situações e em perfis de clientes diferentes.
#
# Com isso obtivemos nosso modelo de previsão de Score de Credito com sucesso.
